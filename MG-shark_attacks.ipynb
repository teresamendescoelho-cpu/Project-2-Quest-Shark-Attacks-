# %% [markdown]
# # MG - Shark Attacks

# %%
import pandas as pd

# %%
url = "https://www.sharkattackfile.net/spreadsheets/GSAF5.xls"

# %%
attacks_df = pd.read_excel(url, engine="xlrd")

# %%
attacks_df
# Out:
#              Date    Year        Type             Country  \
# 0        6th June  2026.0  Unprovoked           Australia
# 1       1st June   2026.0  Unprovoked              Brazil
# 2        1st June  2026.0  Unprovoked              Brazil
# 3        31st May  2026.0  Unprovoked           Australia
# 4        30th May  2026.0  Unprovoked                 USA
# ...           ...     ...         ...                 ...
# 7092  Before 1903     0.0  Unprovoked           AUSTRALIA
# 7093  Before 1903     0.0  Unprovoked           AUSTRALIA
# 7094    1900-1905     0.0  Unprovoked                 USA
# 7095    1883-1889     0.0  Unprovoked              PANAMA
# 7096    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                       State                                Location  \
# 0         Western Australia     Michaelmas Island King George Sound
# 1                   Recife                        Boa Via gem beach
# ...
